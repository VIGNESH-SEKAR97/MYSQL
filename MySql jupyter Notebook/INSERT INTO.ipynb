# %%
# %load_ext sql
# %sql mysql+mysqlconnector://root:Vignesh@localhost/

# %%
# %%sql
# USE COMPANY;
# SELECT * FROM EMPLOYEES;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# TRUNCATE EMPLOYEES;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 0 rows affected.
# []

# %%
# %%sql
# INSERT INTO EMPLOYEES VALUES(1,"VIGNESH","ADVERTISING",30000,1);
# INSERT INTO EMPLOYEES VALUES(2,"VIJAY","COMMERCE",40000,5);
#
# INSERT INTO EMPLOYEES VALUES(3,"AJITH","HR",38000,2),
# (4,"SURYA","FINANCE",45000,3),
# (5,"VIKRAM","MARKETING",23000,3),
# (6,"DHANUSH","CINIMA",53000,4),
# (7,"SIVAKARTHIKEYAN","POLITICS",73000,1),
# (8,"VIMAL","HR",73000,2);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# 1 rows affected.
# 6 rows affected.
# []

# %%
# %%sql
# SELECT * FROM EMPLOYEES;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 8 rows affected.
# [(1, 'VIGNESH', 'ADVERTISING', Decimal('30000'), 1),
#  (2, 'VIJAY', 'COMMERCE', Decimal('40000'), 5),
#  (3, 'AJITH', 'HR', Decimal('38000'), 2),
#  (4, 'SURYA', 'FINANCE', Decimal('45000'), 3),
#  (5, 'VIKRAM', 'MARKETING', Decimal('23000'), 3),
#  (6, 'DHANUSH', 'CINIMA', Decimal('53000'), 4),
#  (7, 'SIVAKARTHIKEYAN', 'POLITICS', Decimal('73000'), 1),
#  (8, 'VIMAL', 'HR', Decimal('73000'), 2)]

# %%
# %%sql
# INSERT INTO EMPLOYEES (E_ID,E_NAME,SALARY) VALUES(9,"RAJINI",76000);
# INSERT INTO EMPLOYEES (E_ID,E_NAME,DEPARTMENT,SALARY) VALUES(10,"KAMAL","FINANCE",27500);
#
# INSERT INTO EMPLOYEES (E_ID,E_NAME,DEPARTMENT,SALARY) VALUES(11,"KARTHI","MARKETING",76000);
# INSERT INTO EMPLOYEES (E_ID,E_NAME,DEPARTMENT,SALARY) VALUES(12,"PRADEEP","ADVERTISING",28000);
#
# INSERT INTO EMPLOYEES VALUES(13,"SILAMBARASAN","COMMERCE",45000,1);
# INSERT INTO EMPLOYEES VALUES(14,"MADHAVAN","ADVERTISING",67000,2);
# INSERT INTO EMPLOYEES VALUES(15,"ARVIND","MARKETING",35500,4);
# INSERT INTO EMPLOYEES VALUES(16,"JIIVA","FINANCE",18500,4);
# INSERT INTO EMPLOYEES VALUES(17,"SIVAJI","POLITICS",60000,5);
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# []

# %%
# %%sql
# SELECT * FROM EMPLOYEES;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 17 rows affected.
# [(1, 'VIGNESH', 'ADVERTISING', Decimal('30000'), 1),
#  (2, 'VIJAY', 'COMMERCE', Decimal('40000'), 5),
#  (3, 'AJITH', 'HR', Decimal('38000'), 2),
#  (4, 'SURYA', 'FINANCE', Decimal('45000'), 3),
#  (5, 'VIKRAM', 'MARKETING', Decimal('23000'), 3),
#  (6, 'DHANUSH', 'CINIMA', Decimal('53000'), 4),
#  (7, 'SIVAKARTHIKEYAN', 'POLITICS', Decimal('73000'), 1),
#  (8, 'VIMAL', 'HR', Decimal('73000'), 2),
#  (9, 'RAJINI', None, Decimal('76000'), None),
#  (10, 'KAMAL', 'FINANCE', Decimal('27500'), None),
#  (11, 'KARTHI', 'MARKETING', Decimal('76000'), None),
#  (12, 'PRADEEP', 'ADVERTISING', Decimal('28000'), None),
#  (13, 'SILAMBARASAN', 'COMMERCE', Decimal('45000'), 1),
#  (14, 'MADHAVAN', 'ADVERTISING', Decimal('67000'), 2),
#  (15, 'ARVIND', 'MARKETING', Decimal('35500'), 4),
#  (16, 'JIIVA', 'FINANCE', Decimal('18500'), 4),
#  (17, 'SIVAJI', 'POLITICS', Decimal('60000'), 5)]

# %%
# %%sql
# INSERT INTO BRANCH VALUES(1,"CHENNAI","TAMIL NADU"),
# (2,"BANGALORE","KARNATAKA"),
# (3,"MUMBAI","MAHARASTRA"),
# (4,"HYDRABAD","TELANGANA"),
# (5,"DELHI","DELHI");
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 5 rows affected.
# []

# %%
# %%sql
# SELECT * FROM BRANCH;
# Out:
#  * mysql+mysqlconnector://root:***@localhost/
# 5 rows affected.
# [(1, 'CHENNAI', 'TAMIL NADU'),
#  (2, 'BANGALORE', 'KARNATAKA'),
#  (3, 'MUMBAI', 'MAHARASTRA'),
#  (4, 'HYDRABAD', 'TELANGANA'),
#  (5, 'DELHI', 'DELHI')]
